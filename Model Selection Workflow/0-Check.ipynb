# %%
from src import Config, CustomModel
from pathlib import Path

# %%
PATH = Path('/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/configs/first_try.yaml')
cfg = Config.load_cfg(PATH)
model = CustomModel(cfg)
# Out:
# {'data': {'train_path': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/data/dddata.csv', 'test_path': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/data/application_test.csv', 'target_col': 'TARGET', 'drop_cols': ['SK_ID_CURR'], 'test_size': 0.2}, 'model': {'name': 'LogisticRegression', 'fixed_params': {}, 'search_space': {'C': {'type': 'int', 'low': 1, 'high': 1000}}}, 'cv': {'metric': 'ROC_AUC', 'cv_num': 2, 'n_trials': 1}, 'tracker': {'exp_name': 'Tune', 'exp_dir': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/experiments'}}

# %%
model.fit_optuna()
# Out:
# [I 2026-09-26 23:29:16,575] Using an existing study with name 'LogisticRegression' instead of creating a new one.
# [I 2026-09-26 23:29:16,645] Trial 11 finished with value: 0.8968543496695947 and parameters: {'C': 375}. Best is trial 7 with value: 0.8968543496695947.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.fit_optuna()
#
# File ~/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/src/model.py:75, in CustomModel.fit_optuna(self)
#      73 study.optimize(objective, n_trials=self.config.cv.n_trials)
#      74 best_params = study.best_params
# ---> 75 self.save_experiment(self.config, best_params, study.best_value)
#
# File ~/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/src/model.py:89, in CustomModel.save_experiment(self, config, params, result)
#      87 def save_experiment(self, config, params, result):
#      88     tracker = ExperimentTracker(config, params, result)
# ---> 89     tracker.save()
#
# File ~/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/src/exp_tracker.py:58, in ExperimentTracker.save(self)
#      56 def save(self):
#      57     now = datetime.now()
# ---> 58     metric_value = self.result['metric']
#      60     # проверить, лучший ли это результат для данной модели
#      61     prev_exp_registry = self.load_previous_exp()
#
# TypeError: 'float' object is not subscriptable
