# %%
from src import Config

# %%
PATH = '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/configs/ex_config.yaml'
cfg = Config(PATH)
# Out:
# {'data': {'train_path': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/data/app_train_eda.csv', 'test_path': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/data/application_test.csv', 'target_col': 'TARGET', 'drop_cols': ['SK_ID_CURR'], 'test_size': 0.2}, 'model': {'name': 'LogisticRegression', 'params': {'verbose': -1}, 'search_space': {'C': {'type': 'int', 'min': 1, 'max': 10}}}, 'train': {'cv_num': 2, 'n_trials': 1, 'save_model': False}, 'general': {'seed': 42}}

# %%
from pprint import pprint
from dataclasses import dataclass

# %%
@dataclass
class ThingData:
    name: str
    weight: int
    price: float

# %%
td = ThingData("Учебник по Python", 100, 102)

# %%
print(repr(td))
# Out:
# ThingData(name='Учебник по Python', weight=100, price=102)
