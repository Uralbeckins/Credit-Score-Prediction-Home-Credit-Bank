# %%
from src import Config, CustomModel
from pathlib import Path

# %%
PATH = Path('/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/configs/first_try.yaml')
cfg = Config.load_cfg(PATH)
model = CustomModel(cfg)
# Out:
# {'data': {'train_path': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/data/ddd.csv', 'test_path': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/data/application_test.csv', 'target_col': 'TARGET', 'drop_cols': ['SK_ID_CURR'], 'test_size': 0.2}, 'model': {'name': 'LogisticRegression', 'fixed_params': {}, 'search_space': {'C': {'type': 'int', 'low': 1, 'high': 1000}}}, 'cv': {'metric': 'ROC_AUC', 'num': 2, 'n_trials': 1}, 'tracker': {'exp_name': 'Tune', 'exp_dir': '/Users/uralgimazov/Desktop/Python/Practice/Credit-Score-Prediction-Home-Credit-Bank/Model Selection Workflow/experiments'}}

# %%
model.fit_optuna(cfg)
