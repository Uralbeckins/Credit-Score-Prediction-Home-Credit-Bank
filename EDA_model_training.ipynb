# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import math
from collections import Counter

pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data downloading

# %% [markdown]
# ### Download the data from Kaggle (for Colab)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# import os

# !mkdir -p ~/.kaggle
# !cp "/content/drive/MyDrive/Colab Notebooks/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle competitions download -c home-credit-default-risk --force

# %%
# import zipfile

# zip_path = "/content/home-credit-default-risk.zip"
# extract_dir = "/content/home-credit-data"

# # Создаём папку для распаковки
# os.makedirs(extract_dir, exist_ok=True)

# # Распаковка
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)

# # Проверим, что распаковано
# os.listdir(extract_dir)

# %%
# For Colab
# app_train = pd.read_csv(f'{extract_dir}/application_train.csv')
# app_test = pd.read_csv(f'{extract_dir}/application_test.csv')

# %%
app_train = pd.read_csv('Data/application_train.csv')
app_test = pd.read_csv('Data/application_test.csv')

# %%
print ("Формат обучающей выборки:", app_train.shape)
print ("Формат тестовой выборки:", app_test.shape)
# Out:
# Формат обучающей выборки: (307511, 122)
# Формат тестовой выборки: (48744, 121)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Counting NaNs:

# %%
missing_pct = (app_train.isnull().sum() / len(app_train) * 100).sort_values(ascending=False)
missing_pct = missing_pct[missing_pct > 1]

plt.figure(figsize=(10, 12))
sns.barplot(x=missing_pct.values, y=missing_pct.index, palette='coolwarm', hue=None)
plt.title("Пропуски в процентах", fontsize=16)
plt.xlabel("Доля пропусков (%)", fontsize=14)
plt.ylabel("Признак", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Можно заметить, что довольно большая часть датасета имеет пропуски (до 70%). В разделе Feature Engineering будем искать решение этой проблемы

# %% [markdown]
# ## Check for the outliers

# %%
def plot_boxplots(features_list, df):
    n = len(features_list)
    cols = 3
    rows = math.ceil(n / cols)

    fig, axes = plt.subplots(rows, cols, figsize=(5*cols, 4*rows))
    axes = axes.flatten()

    for i, feature in enumerate(features_list):
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1

        lower_whisker = Q1 - 1.5 * IQR
        upper_whisker = Q3 + 1.5 * IQR

        outliers = app_train[
            (df[feature] < lower_whisker) |
            (df[feature] > upper_whisker)
        ]

        sns.boxplot(x=df[feature], ax=axes[i], label=f'Количество выбросов: {outliers.shape[0]}\nДоля выбросов: {outliers.shape[0] / app_train.shape[0]:.2%}')
        axes[i].set_title(feature)

    plt.tight_layout()
    plt.show()

# %%
plot_boxplots(
    [
        'DAYS_BIRTH',
        'AMT_INCOME_TOTAL',
        'AMT_CREDIT',
        'AMT_ANNUITY',
        'DAYS_EMPLOYED',
        'OWN_CAR_AGE',
        'DAYS_REGISTRATION',
        'DAYS_ID_PUBLISH',
        'REGION_RATING_CLIENT_W_CITY',
        'REGION_RATING_CLIENT',
        'DAYS_LAST_PHONE_CHANGE',
        'AMT_GOODS_PRICE'
    ],
    app_train
)

# %% [markdown]
# Исходя из данных графиков, можно точно сказать, что выбросами являются:
#
# 1) AMT INCOME_TOTAL - Ежегодный доход в 120 млн. рублей
#
# 2) DAYS_EMPLOYED - Опыт работы на текущем месте работы около 350 тыс. дней
#
# Остальные значения хоть и выбиваются за пределы "усов", но имеют реальное обоснование и их удаление будет неправильным.

# %% [markdown]
# ## Target distribution

# %%
counts = app_train['TARGET'].value_counts().sort_index()

fig, ax = plt.subplots(figsize=(4,5))
sns.barplot(x=counts.index, y=counts.values, ax=ax, palette=['#2b8cbe','#f03b20'])

ax.set_xticklabels(['Good (0)','Bad (1)'])
ax.set_ylabel('Count')
ax.set_title('Target distribution in application_train')

sns.despine(left=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# Можно увидеть явный дисбаланс классов, что будет сильно мешать нашей модели правильно обучаться.

# %% [markdown]
# ## Coefficients of correlation

# %% [markdown]
# Воспользуемся коэффициентами корреляции Пирсона, хоть это и не лучший метод для подбора фичей, однако, он прост и позволяет составить первоначальное представление о данных.

# %%
# Select only numeric columns before calculating correlations
correlations = app_train.select_dtypes(include=np.number).corr()['TARGET'].sort_values()

print('Наивысшая позитивная корреляция:\n', correlations.tail(15))
print('\nНаивысшая негативная коррелация:\n', correlations.head(15))
# Out:
# Наивысшая позитивная корреляция:
#  DEF_60_CNT_SOCIAL_CIRCLE       0.031276
# DEF_30_CNT_SOCIAL_CIRCLE       0.032248
# LIVE_CITY_NOT_WORK_CITY        0.032518
# OWN_CAR_AGE                    0.037612
# DAYS_REGISTRATION              0.041975
# FLAG_DOCUMENT_3                0.044346
# REG_CITY_NOT_LIVE_CITY         0.044395
# FLAG_EMP_PHONE                 0.045982
# REG_CITY_NOT_WORK_CITY         0.050994
# DAYS_ID_PUBLISH                0.051457
# DAYS_LAST_PHONE_CHANGE         0.055218
# REGION_RATING_CLIENT           0.058899
# REGION_RATING_CLIENT_W_CITY    0.060893
# DAYS_BIRTH                     0.078239
# TARGET                         1.000000
# Name: TARGET, dtype: float64
#
# Наивысшая негативная коррелация:
#  EXT_SOURCE_3                 -0.178919
# EXT_SOURCE_2                 -0.160472
# EXT_SOURCE_1                 -0.155317
# DAYS_EMPLOYED                -0.044932
# FLOORSMAX_AVG                -0.044003
# FLOORSMAX_MEDI               -0.043768
# FLOORSMAX_MODE               -0.043226
# AMT_GOODS_PRICE              -0.039645
# REGION_POPULATION_RELATIVE   -0.037227
# ELEVATORS_AVG                -0.034199
# ELEVATORS_MEDI               -0.033863
# FLOORSMIN_AVG                -0.033614
# FLOORSMIN_MEDI               -0.033394
# LIVINGAREA_AVG               -0.032997
# LIVINGAREA_MEDI              -0.032739
# Name: TARGET, dtype: float64

# %% [markdown]
# Таким образом, все данные слабо коррелируют с таргетом. Однако выделяются возраст и некие "внешние источники данных", рассмотрим их подробнее.

# %% [markdown]
# ### Функция для расчета Default Rate, WOE, Information Value

# %% [markdown]
# **Weight of Evidence (WOE)** — показатель, отражающий риск дефолта в отдельном бине признака.
# Рассчитывается как логарифм отношения доли «хороших» клиентов к доле «плохих»:
#
# WOE = ln(Good / Bad)
#
# - WOE > 0 — бин менее рискованный, чем в среднем по выборке
# - WOE < 0 — бин более рискованный
# - WOE ≈ 0 — риск сопоставим со средним
#
# **Information Value (IV)** — агрегированная мера предсказательной силы признака в целом.
# Рассчитывается как сумма вкладов всех бинов:
#
# IV = Σ (Goodᵢ − Badᵢ) · WOEᵢ
#
# Чем выше IV, тем лучше признак разделяет «хороших» и «плохих» заемщиков.
#
# **Интерпретация IV:**
# - IV < 0.02 — неинформативный признак
# - 0.02–0.1 — слабый
# - 0.1–0.3 — средний
# - 0.3–0.5 — сильный
# - IV > 0.5 — возможная утечка данных

# %% [markdown]
# Выбираем признак, разделяем людей на равные по количеству группы при помощи pd.qcut()
#
# Комплексно оцениваем, насколько каждая фича помогает нам выявлять таргет

# %%
# Вспомогательная функция для получения названий интервалов из индекса датафрейма, образованного методом pd.cut()
def get_interval_name(df, interval_round=None):
    output = []

    for val in df.index:
        if isinstance(val, pd.Interval):
            if interval_round is not None:
                left = round(val.left, interval_round)
                right = round(val.right, interval_round)
            else:
                left = val.left
                right = val.right
            output.append(f'{left} - {right}')
        else:
            output.append(str(val))

    return output

# %%
# Вспомогательная функция для получения цветовой палитры на основе значений серии и заданной карты цветов
def get_palette(df, colormap_name, reversed=False):
    norm = mpl.colors.Normalize(
        vmin=df.min(),
        vmax=df.max()
    )

    cmap = mpl.colormaps[colormap_name]

    palette = [cmap(norm(v)) for v in df]

    if reversed == True:
        palette = palette[::-1]

    return palette

# %%
def plot_df_woe_iv(
                feature_name,
                df=app_train,
                bins_dict={'Count': 30, 'Default_Rate': 10, 'WOE & IV': 7},
                x_size=10,
                y_size=7,
                interval_round=None,
                use_raw_values=False
            ):
    
    fig, axes = plt.subplots(2, 2, figsize=(x_size, y_size))
    
    df_plot = df[[feature_name, 'TARGET']].dropna()

    # ---------- DEFAULT RATE ----------
    if use_raw_values:
        df_plot['BIN_DR'] = df_plot[feature_name]
    else:
        df_plot['BIN_DR'] = pd.cut(
            df_plot[feature_name],
            bins=bins_dict['Default_Rate'],
            duplicates='drop'
        )

    df_default_rate = (
        df_plot
        .groupby('BIN_DR', observed=True)
        .agg(
            Count=('TARGET', 'count'),
            Default_Rate=('TARGET', 'mean')
        )
    )

    sns.histplot(
        df_plot[feature_name],
        ax=axes[0,0],
        bins=bins_dict['Count'],
        color=plt.cm.Set2(np.random.randint(0, 8))
    )

    sns.barplot(
        x=get_interval_name(df_default_rate, interval_round),
        y=df_default_rate['Default_Rate'],
        ax=axes[0,1],
        palette=get_palette(df_default_rate['Default_Rate'], 'RdYlGn', reversed=True)
    )

    axes[0,0].set_title('Count')
    axes[0,1].set_title('Default Rate')
    axes[0,1].set_xlabel(feature_name)
    axes[0,0].tick_params(axis='x', rotation=45)
    axes[0,1].tick_params(axis='x', rotation=45)

    # ---------- WOE & IV ----------
    if use_raw_values:
        df_plot['BIN_WOE'] = df_plot[feature_name]
    else:
        df_plot['BIN_WOE'] = pd.qcut(
            df_plot[feature_name],
            q=bins_dict['WOE & IV'],
            duplicates='drop'
        )

    df_woe = (
        df_plot
        .groupby('BIN_WOE', observed=True)['TARGET']
        .value_counts()
        .unstack(fill_value=0)
        .rename(columns={0: 'Good', 1: 'Bad'})
    )

    eps = 1e-9

    df_woe = df_woe.assign(
        Prop_Good=lambda x: x['Good'] / x['Good'].sum(),
        Prop_Bad=lambda x: x['Bad'] / x['Bad'].sum(),
        WOE=lambda x: np.log((x['Prop_Good'] + eps) / (x['Prop_Bad'] + eps)),
        IV=lambda x: (x['Prop_Good'] - x['Prop_Bad']) * x['WOE']
    )

    iv_total = df_woe['IV'].sum()

    sns.barplot(
        x=get_interval_name(df_woe, interval_round),
        y=df_woe['WOE'],
        ax=axes[1,0],
        palette=get_palette(df_woe['WOE'], 'RdYlGn')
    )
    axes[1,0].axhline(0, linestyle='--')
    axes[1,0].set_title('WOE')

    sns.barplot(
        x=get_interval_name(df_woe, interval_round),
        y=df_woe['IV'],
        ax=axes[1,1],
        palette=get_palette(df_woe['IV'], 'PiYG')
    )
    axes[1,1].set_title(f'IV | Total = {iv_total:.4f}')
    axes[1,0].set_xlabel(feature_name)
    axes[1,1].set_xlabel(feature_name)
    axes[1,0].tick_params(axis='x', rotation=45)
    axes[1,1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Возраст

# %% [markdown]
# Сделаем возраст положительным и переведем в года для удобства:

# %%
app_train['AGE_YEARS'] = abs(app_train['DAYS_BIRTH']) / 365
app_test['AGE_YEARS'] = abs(app_test['DAYS_BIRTH']) / 365

app_train.drop('DAYS_BIRTH', axis=1, inplace=True)
app_test.drop('DAYS_BIRTH', axis=1, inplace=True)

# %%
plot_df_woe_iv(
        'AGE_YEARS',
        df=app_train,
        bins_dict={
                'Count': 'auto',
                'Default_Rate': 12,
                'WOE & IV': 10
        },
        interval_round=None,
        x_size=10,
        y_size=7
)

# %% [markdown]
# **Count** & **Default Rate**
#
# - Видно, что нет явных выбросов, распределение возраста довольно обычное, однако, доля невозвратов выше для молодых людей и снижается с ростом возраста.
#
# - Это не повод отказывать молодым людям в кредите полностью, такая "рекомендация" приведет лишь к потере доходов и довольно значимой части рынка для банка. Это повод задуматься о более тщательном их ведении, оценке и контроле.
#
# **WOE**
# - В младших возрастных бинах WOE отрицательный — повышенный риск.
# - С ~40–45 лет WOE становится положительным и растёт, отражая более надёжный профиль старших клиентов.
#
# **IV**
# - IV ≈ 0.08 — признак слабой–средней предсказательной силы.
# - Основной вклад в IV дают крайние возрастные группы, где различия в риске максимальны.

# %% [markdown]
# ### Внешние источники

# %% [markdown]
# Посмотрим внимательнее на "внешние источники данных" и их корреляцию.

# %%
ext_data = app_train[['TARGET', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'AGE_YEARS']]
ext_data_corrs = ext_data.corr() # type: ignore
ext_data_corrs
# Out:
#                 TARGET  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  AGE_YEARS
# TARGET        1.000000     -0.155317     -0.160472     -0.178919  -0.078239
# EXT_SOURCE_1 -0.155317      1.000000      0.213982      0.186846   0.600610
# EXT_SOURCE_2 -0.160472      0.213982      1.000000      0.109167   0.091996
# EXT_SOURCE_3 -0.178919      0.186846      0.109167      1.000000   0.205478
# AGE_YEARS    -0.078239      0.600610      0.091996      0.205478   1.000000

# %% [markdown]
# Удобнее будет отобразить корреляцию в heatmap

# %%
sns.heatmap(ext_data_corrs, cmap=mpl.colormaps['Spectral'], vmin=-0.2)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# Как видно, все источники показывают негативную корреляцию с таргетом. Посмотрим на распределение Default Rate, WOE & IV

# %%
plot_df_woe_iv(
        'EXT_SOURCE_1',
        df=app_train,
        bins_dict={
                'Count': 'auto',
                'Default_Rate': 12,
                'WOE & IV': 10
        },
        interval_round=4,
        x_size=10,
        y_size=7
)

# %% [markdown]
# Вывод: пока что лучший признак как по графику WOE, так и по IV = 0.03465, хотя по корреляция Пирсона показала не самое высокое значение.

# %% [markdown]
# Расссотрим далее **EXT_SOURCE_2**

# %%
plot_df_woe_iv(
        'EXT_SOURCE_2',
        df=app_train,
        bins_dict={
                'Count': 'auto',
                'Default_Rate': 12,
                'WOE & IV': 10
        },
        interval_round=4,
        x_size=10,
        y_size=7
)

# %% [markdown]
# Вывод: аналогично с первым внешним источником.

# %% [markdown]
# Последний: **EXT_SOURCE_3**

# %%
plot_df_woe_iv(
        'EXT_SOURCE_3',
        df=app_train,
        bins_dict={
                'Count': 'auto',
                'Default_Rate': 12,
                'WOE & IV': 10
        },
        interval_round=4,
        x_size=10,
        y_size=7
)

# %% [markdown]
# Вывод: лучший признак по IV = 0.4101

# %% [markdown]
# ### Distribution by credit amount

# %% [markdown]
# Рассмотрим зависимость целевой переменной от размера кредита

# %%
app_train['AMT_CREDIT'] = app_train['AMT_CREDIT'] / 1000
app_test['AMT_CREDIT'] = app_test['AMT_CREDIT'] / 1000

# %%
app_train['AMT_CREDIT'].describe()
# Out:
# count    307511.000000
# mean        599.026000
# std         402.490777
# min          45.000000
# 25%         270.000000
# 50%         513.531000
# 75%         808.650000
# max        4050.000000
# Name: AMT_CREDIT, dtype: float64

# %%
plot_df_woe_iv(
        'AMT_CREDIT',
        df=app_train,
        bins_dict={
                'Count': 50,
                'Default_Rate': 12,
                'WOE & IV': 10
        },
        interval_round=0,
        x_size=10,
        y_size=7
)

# %% [markdown]
# Основные выводы из графика:
#
# **1. Зона повышенного риска (средние суммы кредитов)**
# В диапазоне примерно 300–600 тыс. наблюдается повышенная вероятность дефолта.
# Наиболее рискованный сегмент — 513–604 тыс., где значение WOE достигает минимума.
#
# **2. Относительно безопасные крупные кредиты**
# Для сумм свыше 1.1 млн фиксируется резкий рост WOE.
# Это, как правило, связано с более строгим скорингом и отбором заемщиков с высоким доходом, что снижает относительный риск дефолта.
#
# **3. Парадокс малых кредитов**
# Небольшие займы (до 180 тыс.) имеют положительный WOE, что указывает на их сравнительно низкий риск.
# Вероятная причина — более высокая платежеспособность по таким обязательствам даже при ухудшении финансового положения заемщика.

# %% [markdown]
# ### Distribution by working experience

# %%
# число 365243 используется как заглушка для отсутствующего стажа
app_train['DAYS_EMPLOYED'].replace(365243, np.nan, inplace=True)
app_train['DAYS_EMPLOYED'] = abs(app_train['DAYS_EMPLOYED'])
app_train['YEARS_EMPLOYED'] = app_train['DAYS_EMPLOYED'] / 365.25

app_test['DAYS_EMPLOYED'].replace(365243, np.nan, inplace=True)
app_test['DAYS_EMPLOYED'] = abs(app_test['DAYS_EMPLOYED'])
app_test['YEARS_EMPLOYED'] = app_test['DAYS_EMPLOYED'] / 365.25

# %%
plot_df_woe_iv(
        'YEARS_EMPLOYED',
        df=app_train,
        bins_dict={
                'Count': 'auto',
                'Default_Rate': 12,
                'WOE & IV': 10
        },
        interval_round=1,
        x_size=10,
        y_size=7
)

# %% [markdown]
# **Прямая корреляция с надежностью:**
#
# Мы видим четкую линейную тенденцию: чем дольше человек работает на текущем месте, тем выше его WOE, а значит — тем ниже риск дефолта
#
# **Fun Fact:**
#
# Любопытно, что совсем новички (до 333 дней) рискованны чуть меньше, чем те, кто проработал год, что может быть связано с особенностями прохождения испытательного срока или спецификой найма.

# %% [markdown]
# ### Distribution by population density

# %% [markdown]
# REGION_POPULATION_RELATIVE – Normalized population of region where client lives (higher number means the client lives in more populated region)

# %%
plot_df_woe_iv(
        'REGION_POPULATION_RELATIVE',
        df=app_train,
        bins_dict={
                'Count': 13,
                'Default_Rate': 12,
                'WOE & IV': 10
        },
        interval_round=None,
        x_size=10,
        y_size=7
)

# %% [markdown]
# Вывод: с точки зрения пользы для отличия хороших и плохих клиентов - не самый лучший признак

# %% [markdown]
# ## Other features exploration

# %% [markdown]
# Рассмотрим более подробно другие признаки и их зависимость от целевой переменной

# %%
# application_train = pd.read_csv('Data/application_train.csv')
# application_test = pd.read_csv('Data/application_test.csv')

# %%
def plot_stats(feature, label_rotation=0):
    sns.set_color_codes("pastel")

    feat_counts = app_train[feature].value_counts()
    count_df = pd.DataFrame({feature: feat_counts.index,'Loan count': feat_counts.values})

    # Counting target == 1 cats
    perc_df = app_train[[feature, 'TARGET']].groupby([feature], as_index=False).mean()
    perc_df.sort_values(by='TARGET', ascending=False, inplace=True)

    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))

    s = sns.barplot(ax=ax1, x = feature, y="Loan count", data=count_df, palette='Set2')
    s.set_xticklabels(s.get_xticklabels(), rotation=label_rotation)

    s = sns.barplot(ax=ax2, x = feature, y='TARGET', order=perc_df[feature], data=perc_df, palette='Set2')
    s.set_xticklabels(s.get_xticklabels(), rotation=label_rotation)

    plt.ylabel('Default Rate', fontsize=10)
    plt.tick_params(axis='both', which='major', labelsize=10)
    plt.show()

# %% [markdown]
# ### Contract type

# %%
plot_stats('NAME_CONTRACT_TYPE')

# %% [markdown]
# Интересно, что револьверные кредиты (вероятно, овердрафты или что-то вроде того) составляют меньше 10% от общего количества займов. В то же время процент невозврата сравнительно немал. Хороший повод пересмотреть методику работы с этими займами, а может быть и отказаться от них вовсе.

# %% [markdown]
# ### Client Gender

# %%
plot_stats('CODE_GENDER')

# %% [markdown]
# Женщин-клиентов почти вдвое больше мужчин, при этом мужчины показывают гораздо более высокий риск.

# %% [markdown]
# ### Own Car or Realty

# %%
plot_stats('FLAG_OWN_CAR')
plot_stats('FLAG_OWN_REALTY')

# %% [markdown]
# **Car**
#
# Клиентов, не имеющих автомобиля, в два раза больше, чем тех, у кого он есть. Риск по ним практически одинаковый, клиенты с машиной платят чуть лучше.
#
# **Realty**
#
# По недвижимости обратная картина - клиентов без нее вдвое меньше. Риск по владельцам недвижимости также чуть меньше.

# %% [markdown]
# ### Family status

# %%
plot_stats('NAME_FAMILY_STATUS', 90)

# %% [markdown]
# В то время как большинство клиентов состоит в браке, ниаболее рискованы клиенты в гражданском браке и одинокие. Вдовцы показывают минимальный риск.

# %% [markdown]
# ### Children count

# %%
plot_stats('CNT_CHILDREN')

# %% [markdown]
# Большинство клиентов бездетны. При этом клиенты с 9 и 11 детьми показывют полный невозврат. Однако необходимо проверить, насколько эти данные статистически значимы:

# %%
app_train.CNT_CHILDREN.value_counts().tail()
# Out:
# CNT_CHILDREN
# 9     2
# 12    2
# 10    2
# 19    2
# 11    1
# Name: count, dtype: int64

# %% [markdown]
# Как показывает подсчет значений, эти данные не имеют веса - всего по 2 клиента обеих категорий (9 и 11 детей). Однако, все 4 вышли в дефолт, равно как и половина клиентов с 6 детьми.
#
# Поэтому объединим всех клиентов, имеющих 4 и более детей в отдельную категорию 4+:

# %%
app_train[app_train['CNT_CHILDREN'] > 3]['CNT_CHILDREN'] = 4
app_test[app_test['CNT_CHILDREN'] > 3]['CNT_CHILDREN'] = 4

# %% [markdown]
# ### Family members count

# %%
app_train.CNT_FAM_MEMBERS = app_train.CNT_FAM_MEMBERS.fillna(0).astype(int)
app_test.CNT_FAM_MEMBERS = app_test.CNT_FAM_MEMBERS.fillna(0).astype(int)
plot_stats('CNT_FAM_MEMBERS')

# %%
app_train.CNT_FAM_MEMBERS.value_counts().tail()
# Out:
# CNT_FAM_MEMBERS
# 20    2
# 16    2
# 13    1
# 15    1
# 11    1
# Name: count, dtype: int64

# %% [markdown]
# Наблюдается та же закономерность — чем меньше членов в семье, тем выше вероятность возврата кредита. Для решения проблем с малочисленными классами, поступим также как и с CNT_CHILDREN

# %%
app_train[app_train['CNT_FAM_MEMBERS'] > 5]['CNT_FAM_MEMBERS'] = 6
app_test[app_test['CNT_FAM_MEMBERS'] > 5]['CNT_FAM_MEMBERS'] = 6

# %% [markdown]
# ### Income type (Пересмотреть)

# %%
plot_stats('NAME_INCOME_TYPE', 90)

# %%
app_train.NAME_INCOME_TYPE.value_counts()
# Out:
# NAME_INCOME_TYPE
# Working                 158774
# Commercial associate     71617
# Pensioner                55362
# State servant            21703
# Unemployed                  22
# Student                     18
# Businessman                 10
# Maternity leave              5
# Name: count, dtype: int64

# %% [markdown]
# В связи с очень малым количеством людей в классах **['Unemployed', 'Student', 'Businessman', 'Maternity leave']**, объединим их в одну группу - other, дабы уменьшить переобучение модели

# %% [markdown]
# ### Working sphere

# %%
plot_stats('OCCUPATION_TYPE', 90)

# %%
app_train.OCCUPATION_TYPE.value_counts()
# Out:
# OCCUPATION_TYPE
# Laborers                 55186
# Sales staff              32102
# Core staff               27570
# Managers                 21371
# Drivers                  18603
# High skill tech staff    11380
# Accountants               9813
# Medicine staff            8537
# Security staff            6721
# Cooking staff             5946
# Cleaning staff            4653
# Private service staff     2652
# Low-skill Laborers        2093
# Waiters/barmen staff      1348
# Secretaries               1305
# Realty agents              751
# HR staff                   563
# IT staff                   526
# Name: count, dtype: int64

# %% [markdown]
# Здесь вызывают интерес водители и сотрудники безопасности, которые довольно многочисленны и выходят на проблемы чаще других категорий.

# %% [markdown]
# ### Education type

# %%
plot_stats('NAME_EDUCATION_TYPE', 90)

# %% [markdown]
# Чем выше образование, тем лучше возвратность, очевидно.

# %% [markdown]
# # Data Cleaning and Feature Engineering

# %% [markdown]
# ## Drop the outliers

# %%
upper = app_train['AMT_INCOME_TOTAL'].quantile(0.99)
app_train['AMT_INCOME_TOTAL'] = app_train['AMT_INCOME_TOTAL'].clip(upper=upper)

app_train = app_train[app_train['DAYS_EMPLOYED'] != app_train['DAYS_EMPLOYED'].max()]

# %% [markdown]
# ## Deal with NaNs

# %%
# Если у человека нет машины, то, очевидно, у него нет и возраста автомобиля, поэтому просто заменим NaN на 0
app_train.OWN_CAR_AGE.fillna(0, inplace=True)
app_test.OWN_CAR_AGE.fillna(0, inplace=True)

# %%
# Сразу же удалим столбцы, в которых слишком большой процент пропусков
missing_pct = (app_train.isnull().sum() / len(app_train) * 100).sort_values(ascending=False)
missing_pct = missing_pct[missing_pct > 1]

# %%
cols_to_drop = missing_pct.index[missing_pct > 57].tolist()
app_train = app_train.drop(columns=cols_to_drop)
app_test = app_test.drop(columns=cols_to_drop)

target = app_train['TARGET']
app_train.drop(columns=['TARGET'], inplace=True)

num_cols = app_train.select_dtypes(include=['float64', 'int64']).columns.tolist()
cat_cols = app_train.select_dtypes(exclude=['float64', 'int64']).columns.tolist()

# %%
from sklearn.impute import SimpleImputer

imp_num = SimpleImputer(strategy='median')
app_train[num_cols] = imp_num.fit_transform(app_train[num_cols])

app_test[num_cols] = imp_num.transform(app_test[num_cols])

imp_cat = SimpleImputer(strategy='most_frequent')
app_train[cat_cols] = imp_cat.fit_transform(app_train[cat_cols].astype(str))
app_test[cat_cols] = imp_cat.transform(app_test[cat_cols].astype(str))

# %% [markdown]
# ## Imputing NaN values (Вычислительные сложности ....)

# %% [markdown]
# Далее мы воспользуемся KNNImputer, который по соседним числовым значениям восстановит нам все NaN-значения
#
# Но перед этим необходимо отнормализовать значения, иначе фичи с большими числами (например, доход в миллионах) будут давить на «близость» соседей

# %%
# # Выберем только числовые признаки
# num_cols = app_train.select_dtypes(include=['int64', 'float64']).columns.tolist()
# num_cols.remove('TARGET')
# # num_cols

# %%
# len(num_cols + ordinal_enc_cols)

# %%
# for df in [app_train, app_test]:
#     df[df.select_dtypes('float64').columns] = df.select_dtypes('float64').astype('float32')
#     df[df.select_dtypes('int64').columns]   = df.select_dtypes('int64').astype('int32')

# app_train.dtypes.value_counts()

# %%
# import pandas as pd
# from sklearn.feature_selection import mutual_info_classif
# from sklearn.impute import SimpleImputer

# def compute_mutual_info(df, target_col):
#     """
#     Считает mutual information для всех признаков (числовых и категориальных) относительно таргета.
#     df : pd.DataFrame
#     target_col : str
#     """
#     X = df.drop(columns=[target_col])
#     y = df[target_col]

#     # разделяем на числовые и категориальные
#     num_cols = X.select_dtypes(include=['int64', 'float64', 'int32', 'float32']).columns
#     cat_cols = X.select_dtypes(exclude=['int64', 'float64', 'int32', 'float32']).columns

#     # Имьютация
#     X_num = pd.DataFrame(SimpleImputer(strategy='median').fit_transform(X[num_cols]),
#                          columns=num_cols, index=X.index)
#     X_cat = pd.DataFrame(SimpleImputer(strategy='most_frequent').fit_transform(X[cat_cols].astype(str)),
#                          columns=cat_cols, index=X.index)

#     # объединяем обратно
#     X_all = pd.concat([X_num, X_cat], axis=1)

#     # маска дискретных колонок
#     discrete_mask = [col in cat_cols for col in X_all.columns]

#     # mutual info
#     mi = mutual_info_classif(X_all, y, discrete_features=discrete_mask, random_state=42)

#     # результат
#     mi_series = pd.Series(mi, index=X_all.columns, name='mutual_info').sort_values(ascending=False)
#     return mi_series.to_frame()

# %%
# num_cols = app_train.select_dtypes(include=['int64', 'float64', 'int32', 'float32']).columns.tolist()

# %%
# num_cols.sort()
# # num_cols

# %%
# # target = app_train['TARGET']
# # app_train.drop(columns=['TARGET'], inplace=True)
# num_cols.remove('AGE_YEARS')

# %%
# X_num = pd.DataFrame(SimpleImputer(strategy='median').fit_transform(app_train[num_cols]),
#                          columns=num_cols, index=app_train.index)

# %%
# mi = mutual_info_classif(X_num, target, discrete_features=False, random_state=42)

# %%
# mi_series = pd.Series(mi, index=X_num.columns, name='mutual_info').sort_values(ascending=False)
# mi_series.to_frame()
# mi_series = mi_series[mi_series > 0.005]

# plt.figure(figsize=(5, 25))
# sns.barplot(x='mutual_info', y=mi_series.index, data=mi_series.reset_index())
# plt.title('Mutual Information with Target')
# plt.show()

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.impute import KNNImputer

# # target = app_train['TARGET']
# # app_train.drop(columns=['TARGET'], inplace=True)

# KNN_scaler = StandardScaler()
# app_train_scaled = KNN_scaler.fit_transform(app_train[num_cols + ordinal_enc_cols])
# app_test_scaled = KNN_scaler.transform(app_test[num_cols + ordinal_enc_cols])

# KNN_imputer = KNNImputer(n_neighbors=3)
# app_train_imputed = KNN_imputer.fit_transform(app_train_scaled)
# app_test_imputed = KNN_imputer.transform(app_test_scaled)

# %% [markdown]
# ## Column dtypes and categorical data handling

# %% [markdown]
# Далее посмотрим, распределение типов данных в датасете:

# %%
app_train.dtypes.value_counts()
# Out:
# float64    85
# object     15
# Name: count, dtype: int64

# %% [markdown]
# 16 колонок в датасете имеют тип "объект" и нам нужно их заэнкодить. Осталось выбрать вариант энкодера

# %%
app_train.select_dtypes(include=[object]).apply(pd.Series.nunique).sort_values(ascending=False)
# Out:
# ORGANIZATION_TYPE             58
# OCCUPATION_TYPE               19
# NAME_TYPE_SUITE                8
# NAME_INCOME_TYPE               8
# WALLSMATERIAL_MODE             8
# WEEKDAY_APPR_PROCESS_START     7
# NAME_FAMILY_STATUS             6
# NAME_HOUSING_TYPE              6
# NAME_EDUCATION_TYPE            5
# HOUSETYPE_MODE                 4
# CODE_GENDER                    3
# EMERGENCYSTATE_MODE            3
# NAME_CONTRACT_TYPE             2
# FLAG_OWN_CAR                   2
# FLAG_OWN_REALTY                2
# dtype: int64

# %%
app_train.NAME_EDUCATION_TYPE.unique()
# Out:
# array(['Secondary / secondary special', 'Higher education',
#        'Incomplete higher', 'Lower secondary', 'Academic degree'],
#       dtype=object)

# %% [markdown]
# Как мы видим, можно отранжировать типы образования (например, по возрастанию) и каждому типу присвоить свое число.

# %%
# Выделим все колонки с категориальными признаками
object_cols = app_train.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# Далее займемся энкодерами
#
# Фичи, в которых всего два уникальных значения будем кодировать при помощи OrdinalEncoder:

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_enc_cols = [
    'NAME_EDUCATION_TYPE',
    'CODE_GENDER',
    'FLAG_OWN_CAR',
    'NAME_CONTRACT_TYPE',
    'FLAG_OWN_REALTY',
    'EMERGENCYSTATE_MODE'
]

# Формируем список категорий для 'NAME_EDUCATION_TYPE'
categories = [
    [
        'Lower secondary',
        'Secondary / secondary special',
        'Incomplete higher',
        'Higher education',
        'Academic degree'
    ]
]

# Для остальных колонок получаем уникальные значения в порядке появления
for col in ordinal_enc_cols[1:]:
    cats = list(app_train[col].unique())
    categories.append(cats)

ordinal_enc = OrdinalEncoder(
    categories=categories,
    handle_unknown='use_encoded_value',
    unknown_value=-1,
    dtype=int
)

app_train[ordinal_enc_cols] = ordinal_enc.fit_transform(app_train[ordinal_enc_cols])
app_test[ordinal_enc_cols] = ordinal_enc.fit_transform(app_test[ordinal_enc_cols])

# %% [markdown]
# А всё остальное - OneHotEncoderом

# %%
one_hot_enc_cols = [
    'ORGANIZATION_TYPE',
    'OCCUPATION_TYPE',
    'NAME_INCOME_TYPE',
    'NAME_TYPE_SUITE',
    'WALLSMATERIAL_MODE',
    'WEEKDAY_APPR_PROCESS_START',
    'NAME_FAMILY_STATUS',
    'NAME_HOUSING_TYPE',
    'HOUSETYPE_MODE'
]

app_train = pd.get_dummies(app_train, columns=one_hot_enc_cols)
app_test = pd.get_dummies(app_test, columns=one_hot_enc_cols)

# %%
print('После OneHot:')
print('Формат тренировочной выборки: ', app_train.shape)
print('Формат тестовой выборки: ', app_test.shape)
# Out:
# После OneHot:
# Формат тренировочной выборки:  (307510, 215)
# Формат тестовой выборки:  (48744, 213)

# %% [markdown]
# Теперь у нас появились столбцы, которых нет в обеих выборках. Нам поможет метод align()

# %%
# Выравнивание - сохранятся только столбцы. имеющиеся в обоих датафреймах
app_train, app_test = app_train.align(app_test, join = 'inner', axis = 1)

print('После align():')
print('Формат тренировочной выборки: ', app_train.shape)
print('Формат тестовой выборки: ', app_test.shape)

# Add target back into the data
app_train['TARGET'] = target
# Out:
# После align():
# Формат тренировочной выборки:  (307510, 213)
# Формат тестовой выборки:  (48744, 213)

# %% [markdown]
# ## Polinomial features

# %% [markdown]
# Выберем только важные признаки и лишь из них сделаем полиномы, во избежание переобучения:

# %%
# Cоздадим новый датафрейм для полиномиальных признаков
poly_features = app_train[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'AGE_YEARS']]
poly_features_test = app_test[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'AGE_YEARS']]

# %%
from sklearn.preprocessing import PolynomialFeatures

# Создадим полиномиальный объект степени 3
poly_transformer = PolynomialFeatures(degree = 3)

# Тренировка полиномиальных признаков
poly_transformer.fit(poly_features)

# Трансформация признаков
poly_features = poly_transformer.transform(poly_features)
poly_features_test = poly_transformer.transform(poly_features_test)
print('Формат полиномиальных признаков: ', poly_features.shape)
# Out:
# Формат полиномиальных признаков:  (307510, 35)

# %% [markdown]
# Присвоим признакам имена при помощи метода get_feature_names:

# %%
poly_transformer.get_feature_names_out(input_features = ['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'AGE_YEARS'])[:15]
# Out:
# array(['1', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'AGE_YEARS',
#        'EXT_SOURCE_1^2', 'EXT_SOURCE_1 EXT_SOURCE_2',
#        'EXT_SOURCE_1 EXT_SOURCE_3', 'EXT_SOURCE_1 AGE_YEARS',
#        'EXT_SOURCE_2^2', 'EXT_SOURCE_2 EXT_SOURCE_3',
#        'EXT_SOURCE_2 AGE_YEARS', 'EXT_SOURCE_3^2',
#        'EXT_SOURCE_3 AGE_YEARS', 'AGE_YEARS^2'], dtype=object)

# %% [markdown]
# Итого 35 полиномиальных и производных признаков. Проверих их корреляцию с таргетом.

# %%
# Датафрейм для новых фич
poly_features = pd.DataFrame(poly_features,
                             columns = poly_transformer.get_feature_names_out(['EXT_SOURCE_1', 'EXT_SOURCE_2',
                                                                           'EXT_SOURCE_3', 'AGE_YEARS']))
poly_features_test = pd.DataFrame(poly_features_test,
                                  columns = poly_transformer.get_feature_names_out(['EXT_SOURCE_1', 'EXT_SOURCE_2',
                                                                                'EXT_SOURCE_3', 'AGE_YEARS']))

# Добавим таргет
poly_features_with_TARGET = poly_features.copy()
poly_features_with_TARGET['TARGET'] = target

# Рассчитаем корреляцию
poly_corrs = poly_features_with_TARGET.corr()['TARGET'].sort_values()

# Отобразим признаки с наивысшей корреляцией
print(poly_corrs.head(10))
print(poly_corrs.tail(5))
# Out:
# EXT_SOURCE_2 EXT_SOURCE_3                -0.178014
# EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3   -0.173867
# EXT_SOURCE_2 EXT_SOURCE_3 AGE_YEARS      -0.166366
# EXT_SOURCE_2^2 EXT_SOURCE_3              -0.161767
# EXT_SOURCE_2 EXT_SOURCE_3^2              -0.158300
# EXT_SOURCE_1 EXT_SOURCE_2                -0.152347
# EXT_SOURCE_1 EXT_SOURCE_3                -0.150282
# EXT_SOURCE_2                             -0.146858
# EXT_SOURCE_2 AGE_YEARS                   -0.143552
# EXT_SOURCE_1 EXT_SOURCE_2^2              -0.143275
# Name: TARGET, dtype: float64
# AGE_YEARS     -0.071492
# AGE_YEARS^2   -0.069996
# AGE_YEARS^3   -0.067779
# TARGET         1.000000
# 1                   NaN
# Name: TARGET, dtype: float64

# %% [markdown]
# Итак, некоторые признаки показывают более высокую корреляцию, чем исходные. Есть смысл попробовать обучение с ними и без них. Для этого присоединим полиномиальные признаки к основному DF.

# %%
# Объединим тренировочные датафреймы
poly_features['SK_ID_CURR'] = app_train['SK_ID_CURR']
app_train_poly = app_train.merge(poly_features, on = 'SK_ID_CURR', how = 'left')

# Объединим тестовые датафреймы
poly_features_test['SK_ID_CURR'] = app_test['SK_ID_CURR']
app_test_poly = app_test.merge(poly_features_test, on = 'SK_ID_CURR', how = 'left')

# Посмотрим формат
print('Тренировочная выборка с полиномиальными признаками: ', app_train_poly.shape)
print('Тестовая выборка с полиномиальными признаками: ', app_test_poly.shape)
# Out:
# Тренировочная выборка с полиномиальными признаками:  (307510, 249)
# Тестовая выборка с полиномиальными признаками:  (48744, 248)

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Model evaluation functions

# %% [markdown]
# Создадим функцию для подбора гиперпараметров при помощи библиотеки Optuna

# %%
import optuna
from sklearn.model_selection import cross_val_score, StratifiedKFold

def optuna_tune(model_class, param_space_func, X, y, n_trials=60, cv_num=5):

    def objective(trial):
        params = param_space_func(trial)
        model = model_class(**params)
        cv= StratifiedKFold(n_splits=cv_num, shuffle=True, random_state=42)

        # Get AUC_score from cross validation
        score = cross_val_score(
            model, X, y,
            cv=cv,
            scoring='roc_auc',
            n_jobs=-1
        ).mean()
        return score

    study = optuna.create_study(direction='maximize', storage="sqlite:///optuna_logs.db", study_name=model_class.__name__, load_if_exists=True)
    study.optimize(objective, n_trials=n_trials)
    print("Лучшие параметры:", study.best_params)
    print("Лучший AUC:", study.best_value)

    # Fit the best model with the entire dataset for easy production use
    best_model = model_class(**study.best_params)
    best_model.fit(X, y)

    return study, best_model

# %% [markdown]
# ## 1) Get Baseline - Logistic Regression

# %% [markdown]
# Разделим app_train на тренировочную и тестовую выборку

# %%
from sklearn.model_selection import train_test_split

app_train.drop(columns=['TARGET'], inplace=True)

X_train, X_val, y_train, y_val = train_test_split(app_train, target, test_size=0.2, random_state=42, stratify=target)
X_kaggle = app_test

# %% [markdown]
# Создадим функцию для построения кривой ROC и создания csv-файла, который позже пойдет в Kaggle для сабмита

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

def get_score(pipeline, csv_name):

    y_kaggle_proba = pipeline.predict_proba(X_kaggle)[:, 1]
    y_val_proba = pipeline.predict_proba(X_val)[:, 1]

    # Make submission-file for Kaggle
    submission = pd.DataFrame({'SK_ID_CURR': X_kaggle['SK_ID_CURR'], 'TARGET': y_kaggle_proba})
    submission['SK_ID_CURR'] = submission['SK_ID_CURR'].astype(int)
    submission.to_csv(csv_name, index=False)

    # Plotting ROC-curve
    fpr, tpr, _ = roc_curve(y_val,  y_val_proba)
    auc = roc_auc_score(y_val, y_val_proba)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}', color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='green') # lame-classifier
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Pipeline: scaler + logistic regression
pipeline_logreg = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(
                                  penalty="elasticnet",
                                  solver="saga",
                                  l1_ratio=0.9,
                                  max_iter=30,
                                  verbose=1,
                                  random_state=42
                                  ))
])

# Learning....
pipeline_logreg.fit(X_train, y_train)

get_score(pipeline_logreg, 'Kaggle Submissions/submission_logreg.csv')
# Out:
# Epoch 1, change: 1
# Epoch 2, change: 0.32175084
# Epoch 3, change: 0.19206327
# Epoch 4, change: 0.13477686
# Epoch 5, change: 0.11008525
# Epoch 6, change: 0.090043492
# Epoch 7, change: 0.075873248
# Epoch 8, change: 0.065509826
# Epoch 9, change: 0.056340077
# Epoch 10, change: 0.049400991
# Epoch 11, change: 0.043431933
# Epoch 12, change: 0.038443417
# Epoch 13, change: 0.034139355
# Epoch 14, change: 0.030520294
# Epoch 15, change: 0.027222209
# Epoch 16, change: 0.024430291
# Epoch 17, change: 0.02197178
# Epoch 18, change: 0.019880214
# Epoch 19, change: 0.01791605
# Epoch 20, change: 0.016254881
# Epoch 21, change: 0.014717895
# Epoch 22, change: 0.01342559
# Epoch 23, change: 0.012209967
# Epoch 24, change: 0.011137391
# Epoch 25, change: 0.010200733
# Epoch 26, change: 0.0093173388
# Epoch 27, change: 0.008525045
# Epoch 28, change: 0.0078256448
# Epoch 29, change: 0.0071862169
# max_iter reached after 11 secondsEpoch 30, change: 0.0065893234

# %% [markdown]
# Выполнение кода заняло 16 секунд
#
# Kaggle Score = 0.69638

# %% [markdown]
# ## 2) Decision Trees

# %% [markdown]
# Проделаем то же самое с простейшим "деревянным" алгоритмом

# %%
from sklearn.tree import DecisionTreeClassifier

def decision_tree_param_space(trial):
    return {
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy", "log_loss"]),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None])
    }

# Optuna tuning
study, best_decision_tree= optuna_tune(DecisionTreeClassifier, decision_tree_param_space, app_train, target, n_trials=1, cv_num=5)

# Get AUC and Kaggle-score
get_score(best_decision_tree, 'submission_decision_tree.csv')
# Out:
# [I 2025-12-25 18:29:30,679] Using an existing study with name 'DecisionTreeClassifier' instead of creating a new one.
# [I 2025-12-25 18:29:37,472] Trial 103 finished with value: 0.7015151182710764 and parameters: {'criterion': 'log_loss', 'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 83 with value: 0.7153202452364742.
# Лучшие параметры: {'criterion': 'log_loss', 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': None}
# Лучший AUC: 0.7153202452364742

# %% [markdown]
# Подбор гиперпараметров занял 3 минуты
#
# Kaggle Score = 0.70369

# %% [markdown]
# ## 3) Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

def random_forest_param_space(trial):
    return {
        "n_estimators": trial.suggest_int("n_estimators", 100, 800),
        "max_depth": trial.suggest_int("max_depth", 5, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False])
    }

# Optuna tuning
study, best_random_forest = optuna_tune(RandomForestClassifier, random_forest_param_space, app_train, target, n_trials=1, cv_num=2)

# Get AUC and Kaggle-score
get_score(best_random_forest, 'submission_random_forest.csv')
# Out:
# [I 2025-12-25 19:37:26,371] Using an existing study with name 'RandomForestClassifier' instead of creating a new one.
# [I 2025-12-25 19:39:36,710] Trial 8 finished with value: 0.7347379873602902 and parameters: {'n_estimators': 548, 'max_depth': 24, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.7383588054279028.
# Лучшие параметры: {'n_estimators': 532, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}
# Лучший AUC: 0.7383588054279028

# %% [markdown]
# Kaggle-score = 0,71350

# %% [markdown]
# ## 4) CatBoost

# %% [markdown]
# В дальнейшем можно попробовать применить catboost на данных без предварительного энкодинга, ибо его алгоритмы должны справиться с этим лучше

# %%
from catboost import CatBoostClassifier

def catboost_param_space(trial):
    return {
        "iterations": trial.suggest_int("iterations", 300, 500),
        "depth": trial.suggest_int("depth", 3, 8),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "random_strength": trial.suggest_float("random_strength", 0, 1),
        "bootstrap_type": "Bernoulli",
        "verbose": 0,
        "random_state": 42
    }


# Optuna tuning
study, best_catboost = optuna_tune(CatBoostClassifier, catboost_param_space, app_train, target, n_trials=1, cv_num=5)

# Get AUC and Kaggle-score
get_score(best_catboost, 'submission_catboost.csv')
# Out:
# [I 2025-12-25 19:44:55,295] Using an existing study with name 'CatBoostClassifier' instead of creating a new one.
# [I 2025-12-25 19:45:26,610] Trial 9 finished with value: 0.7579817047507019 and parameters: {'iterations': 368, 'depth': 6, 'learning_rate': 0.17982092932347649, 'l2_leaf_reg': 9.29714133484718, 'border_count': 120, 'random_strength': 0.8362330622063863}. Best is trial 3 with value: 0.7589806146251737.
# Лучшие параметры: {'iterations': 482, 'depth': 7, 'learning_rate': 0.07165084122688875, 'l2_leaf_reg': 4.442644523588386, 'border_count': 93, 'random_strength': 0.4577034199485801}
# Лучший AUC: 0.7589806146251737
# 0:	learn: 0.6174848	total: 82.6ms	remaining: 39.7s
# 1:	learn: 0.5545999	total: 111ms	remaining: 26.8s
# 2:	learn: 0.5049624	total: 135ms	remaining: 21.6s
# 3:	learn: 0.4622710	total: 164ms	remaining: 19.6s
# 4:	learn: 0.4276719	total: 190ms	remaining: 18.1s
# 5:	learn: 0.3999497	total: 216ms	remaining: 17.1s
# 6:	learn: 0.3756383	total: 242ms	remaining: 16.4s
# 7:	learn: 0.3561606	total: 268ms	remaining: 15.9s
# 8:	learn: 0.3393278	total: 292ms	remaining: 15.4s
# 9:	learn: 0.3257662	total: 318ms	remaining: 15s
# 10:	learn: 0.3147282	total: 343ms	remaining: 14.7s
# 11:	learn: 0.3053950	total: 371ms	remaining: 14.5s
# 12:	learn: 0.2979911	total: 397ms	remaining: 14.3s
# 13:	learn: 0.2909050	total: 424ms	remaining: 14.2s
# 14:	learn: 0.2852422	total: 453ms	remaining: 14.1s
# 15:	learn: 0.2806943	total: 484ms	remaining: 14.1s
# 16:	learn: 0.2764089	total: 513ms	remaining: 14s
# 17:	learn: 0.2729135	total: 539ms	remaining: 13.9s
# 18:	learn: 0.2699640	total: 563ms	remaining: 13.7s
# 19:	learn: 0.2674228	total: 589ms	remaining: 13.6s
# 20:	learn: 0.2652361	total: 616ms	remaining: 13.5s
# 21:	learn: 0.2632544	total: 643ms	remaining: 13.5s
# 22:	learn: 0.2617140	total: 668ms	remaining: 13.3s
# 23:	learn: 0.2602218	total: 693ms	remaining: 13.2s
# 24:	learn: 0.2588733	total: 719ms	remaining: 13.1s
# 25:	learn: 0.2577831	total: 744ms	remaining: 13s
# 26:	learn: 0.2567606	total: 771ms	remaining: 13s
# 27:	learn: 0.2557826	total: 801ms	remaining: 13s
# 28:	learn: 0.2551019	total: 827ms	remaining: 12.9s
# 29:	learn: 0.2543756	total: 855ms	remaining: 12.9s
# 30:	learn: 0.2537978	total: 882ms	remaining: 12.8s
# 31:	learn: 0.2533286	total: 905ms	remaining: 12.7s
# 32:	learn: 0.2528302	total: 933ms	remaining: 12.7s
# 33:	learn: 0.2524279	total: 958ms	remaining: 12.6s
# 34:	learn: 0.2521052	total: 981ms	remaining: 12.5s
# 35:	learn: 0.2517361	total: 1s	remaining: 12.5s
# 36:	learn: 0.2513785	total: 1.03s	remaining: 12.4s
# 37:	learn: 0.2510287	total: 1.06s	remaining: 12.4s
# 38:	learn: 0.2506709	total: 1.09s	remaining: 12.4s
# 39:	learn: 0.2504269	total: 1.11s	remaining: 12.3s
# 40:	learn: 0.2501471	total: 1.15s	remaining: 12.3s
# 41:	learn: 0.2499303	total: 1.18s	remaining: 12.3s
# 42:	learn: 0.2496955	total: 1.21s	remaining: 12.3s
# 43:	learn: 0.2495259	total: 1.24s	remaining: 12.3s
# 44:	learn: 0.2492889	total: 1.27s	remaining: 12.3s
# 45:	learn: 0.2491238	total: 1.3s	remaining: 12.3s
# 46:	learn: 0.2489390	total: 1.32s	remaining: 12.3s
# 47:	learn: 0.2487439	total: 1.35s	remaining: 12.2s
# 48:	learn: 0.2485831	total: 1.38s	remaining: 12.2s
# 49:	learn: 0.2484580	total: 1.4s	remaining: 12.1s
# 50:	learn: 0.2483157	total: 1.43s	remaining: 12.1s
# 51:	learn: 0.2481794	total: 1.46s	remaining: 12.1s
# 52:	learn: 0.2480567	total: 1.48s	remaining: 12s
# 53:	learn: 0.2479599	total: 1.51s	remaining: 12s
# 54:	learn: 0.2478249	total: 1.54s	remaining: 11.9s
# 55:	learn: 0.2477089	total: 1.56s	remaining: 11.9s
# 56:	learn: 0.2476132	total: 1.59s	remaining: 11.8s
# 57:	learn: 0.2475156	total: 1.61s	remaining: 11.8s
# 58:	learn: 0.2474189	total: 1.64s	remaining: 11.7s
# 59:	learn: 0.2473231	total: 1.66s	remaining: 11.7s
# 60:	learn: 0.2472240	total: 1.69s	remaining: 11.7s
# 61:	learn: 0.2471389	total: 1.72s	remaining: 11.6s
# 62:	learn: 0.2470505	total: 1.75s	remaining: 11.6s
# 63:	learn: 0.2469695	total: 1.77s	remaining: 11.6s
# 64:	learn: 0.2468936	total: 1.79s	remaining: 11.5s
# 65:	learn: 0.2468118	total: 1.82s	remaining: 11.5s
# 66:	learn: 0.2467291	total: 1.85s	remaining: 11.4s
# 67:	learn: 0.2466492	total: 1.87s	remaining: 11.4s
# 68:	learn: 0.2465854	total: 1.89s	remaining: 11.3s
# 69:	learn: 0.2465193	total: 1.92s	remaining: 11.3s
# 70:	learn: 0.2464578	total: 1.94s	remaining: 11.2s
# 71:	learn: 0.2463447	total: 1.97s	remaining: 11.2s
# 72:	learn: 0.2462898	total: 1.99s	remaining: 11.2s
# 73:	learn: 0.2462268	total: 2.02s	remaining: 11.1s
# 74:	learn: 0.2461438	total: 2.04s	remaining: 11.1s
# 75:	learn: 0.2460893	total: 2.07s	remaining: 11s
# 76:	learn: 0.2460329	total: 2.09s	remaining: 11s
# 77:	learn: 0.2459416	total: 2.12s	remaining: 11s
# 78:	learn: 0.2458650	total: 2.15s	remaining: 11s
# 79:	learn: 0.2458085	total: 2.17s	remaining: 10.9s
# 80:	learn: 0.2457636	total: 2.2s	remaining: 10.9s
# 81:	learn: 0.2457081	total: 2.23s	remaining: 10.9s
# 82:	learn: 0.2456458	total: 2.25s	remaining: 10.8s
# 83:	learn: 0.2455811	total: 2.27s	remaining: 10.8s
# 84:	learn: 0.2455038	total: 2.3s	remaining: 10.7s
# 85:	learn: 0.2454337	total: 2.33s	remaining: 10.7s
# 86:	learn: 0.2453778	total: 2.35s	remaining: 10.7s
# 87:	learn: 0.2453255	total: 2.37s	remaining: 10.6s
# 88:	learn: 0.2452668	total: 2.4s	remaining: 10.6s
# 89:	learn: 0.2452102	total: 2.42s	remaining: 10.6s
# 90:	learn: 0.2451534	total: 2.45s	remaining: 10.5s
# 91:	learn: 0.2450989	total: 2.47s	remaining: 10.5s
# 92:	learn: 0.2450565	total: 2.49s	remaining: 10.4s
# 93:	learn: 0.2450182	total: 2.52s	remaining: 10.4s
# 94:	learn: 0.2449563	total: 2.54s	remaining: 10.4s
# 95:	learn: 0.2448849	total: 2.57s	remaining: 10.3s
# 96:	learn: 0.2448331	total: 2.6s	remaining: 10.3s
# 97:	learn: 0.2447875	total: 2.62s	remaining: 10.3s
# 98:	learn: 0.2447284	total: 2.65s	remaining: 10.3s
# 99:	learn: 0.2446881	total: 2.67s	remaining: 10.2s
# 100:	learn: 0.2446351	total: 2.7s	remaining: 10.2s
# 101:	learn: 0.2445799	total: 2.72s	remaining: 10.1s
# 102:	learn: 0.2445402	total: 2.75s	remaining: 10.1s
# 103:	learn: 0.2444917	total: 2.77s	remaining: 10.1s
# 104:	learn: 0.2444395	total: 2.8s	remaining: 10.1s
# 105:	learn: 0.2443904	total: 2.82s	remaining: 10s
# 106:	learn: 0.2443286	total: 2.85s	remaining: 9.99s
# 107:	learn: 0.2442763	total: 2.88s	remaining: 9.97s
# 108:	learn: 0.2442291	total: 2.91s	remaining: 9.95s
# 109:	learn: 0.2441933	total: 2.93s	remaining: 9.91s
# 110:	learn: 0.2441250	total: 2.96s	remaining: 9.88s
# 111:	learn: 0.2440774	total: 2.98s	remaining: 9.85s
# 112:	learn: 0.2440448	total: 3.01s	remaining: 9.82s
# 113:	learn: 0.2439734	total: 3.09s	remaining: 9.99s
# 114:	learn: 0.2439269	total: 3.13s	remaining: 10s
# 115:	learn: 0.2438922	total: 3.16s	remaining: 9.97s
# 116:	learn: 0.2438597	total: 3.18s	remaining: 9.93s
# 117:	learn: 0.2438127	total: 3.21s	remaining: 9.89s
# 118:	learn: 0.2437680	total: 3.23s	remaining: 9.85s
# 119:	learn: 0.2437298	total: 3.25s	remaining: 9.81s
# 120:	learn: 0.2436863	total: 3.28s	remaining: 9.78s
# 121:	learn: 0.2436344	total: 3.31s	remaining: 9.75s
# 122:	learn: 0.2436074	total: 3.33s	remaining: 9.72s
# 123:	learn: 0.2435879	total: 3.35s	remaining: 9.69s
# 124:	learn: 0.2435504	total: 3.38s	remaining: 9.66s
# 125:	learn: 0.2435102	total: 3.41s	remaining: 9.63s
# 126:	learn: 0.2434554	total: 3.44s	remaining: 9.61s
# 127:	learn: 0.2434091	total: 3.46s	remaining: 9.58s
# 128:	learn: 0.2433685	total: 3.49s	remaining: 9.55s
# 129:	learn: 0.2433378	total: 3.51s	remaining: 9.52s
# 130:	learn: 0.2432789	total: 3.55s	remaining: 9.5s
# 131:	learn: 0.2432191	total: 3.57s	remaining: 9.47s
# 132:	learn: 0.2431864	total: 3.59s	remaining: 9.43s
# 133:	learn: 0.2431414	total: 3.62s	remaining: 9.39s
# 134:	learn: 0.2431072	total: 3.64s	remaining: 9.36s
# 135:	learn: 0.2430648	total: 3.67s	remaining: 9.33s
# 136:	learn: 0.2430214	total: 3.69s	remaining: 9.3s
# 137:	learn: 0.2429765	total: 3.72s	remaining: 9.27s
# 138:	learn: 0.2429480	total: 3.75s	remaining: 9.24s
# 139:	learn: 0.2429200	total: 3.77s	remaining: 9.21s
# 140:	learn: 0.2428889	total: 3.79s	remaining: 9.17s
# 141:	learn: 0.2428337	total: 3.82s	remaining: 9.14s
# 142:	learn: 0.2427926	total: 3.84s	remaining: 9.11s
# 143:	learn: 0.2427543	total: 3.87s	remaining: 9.08s
# 144:	learn: 0.2427085	total: 3.89s	remaining: 9.05s
# 145:	learn: 0.2426732	total: 3.92s	remaining: 9.02s
# 146:	learn: 0.2426472	total: 3.94s	remaining: 8.99s
# 147:	learn: 0.2426157	total: 3.97s	remaining: 8.95s
# 148:	learn: 0.2425728	total: 4s	remaining: 8.93s
# 149:	learn: 0.2425435	total: 4.02s	remaining: 8.89s
# 150:	learn: 0.2424923	total: 4.04s	remaining: 8.86s
# 151:	learn: 0.2424556	total: 4.07s	remaining: 8.83s
# 152:	learn: 0.2424136	total: 4.09s	remaining: 8.8s
# 153:	learn: 0.2423776	total: 4.11s	remaining: 8.76s
# 154:	learn: 0.2423461	total: 4.14s	remaining: 8.73s
# 155:	learn: 0.2423160	total: 4.16s	remaining: 8.69s
# 156:	learn: 0.2422760	total: 4.18s	remaining: 8.66s
# 157:	learn: 0.2422371	total: 4.21s	remaining: 8.63s
# 158:	learn: 0.2422087	total: 4.23s	remaining: 8.6s
# 159:	learn: 0.2421873	total: 4.25s	remaining: 8.56s
# 160:	learn: 0.2421513	total: 4.28s	remaining: 8.53s
# 161:	learn: 0.2421182	total: 4.3s	remaining: 8.49s
# 162:	learn: 0.2420822	total: 4.32s	remaining: 8.46s
# 163:	learn: 0.2420396	total: 4.35s	remaining: 8.44s
# 164:	learn: 0.2420289	total: 4.38s	remaining: 8.41s
# 165:	learn: 0.2419954	total: 4.4s	remaining: 8.37s
# 166:	learn: 0.2419340	total: 4.42s	remaining: 8.35s
# 167:	learn: 0.2419008	total: 4.45s	remaining: 8.31s
# 168:	learn: 0.2418451	total: 4.47s	remaining: 8.28s
# 169:	learn: 0.2418020	total: 4.5s	remaining: 8.26s
# 170:	learn: 0.2417695	total: 4.52s	remaining: 8.22s
# 171:	learn: 0.2417478	total: 4.54s	remaining: 8.19s
# 172:	learn: 0.2417083	total: 4.57s	remaining: 8.16s
# 173:	learn: 0.2416793	total: 4.59s	remaining: 8.13s
# 174:	learn: 0.2416384	total: 4.62s	remaining: 8.1s
# 175:	learn: 0.2416119	total: 4.64s	remaining: 8.07s
# 176:	learn: 0.2415856	total: 4.67s	remaining: 8.04s
# 177:	learn: 0.2415539	total: 4.69s	remaining: 8.01s
# 178:	learn: 0.2415078	total: 4.72s	remaining: 7.99s
# 179:	learn: 0.2414775	total: 4.74s	remaining: 7.96s
# 180:	learn: 0.2414377	total: 4.78s	remaining: 7.94s
# 181:	learn: 0.2413993	total: 4.82s	remaining: 7.94s
# 182:	learn: 0.2413678	total: 4.85s	remaining: 7.92s
# 183:	learn: 0.2413302	total: 4.87s	remaining: 7.89s
# 184:	learn: 0.2412986	total: 4.9s	remaining: 7.86s
# 185:	learn: 0.2412719	total: 4.92s	remaining: 7.83s
# 186:	learn: 0.2412481	total: 4.95s	remaining: 7.8s
# 187:	learn: 0.2412280	total: 4.97s	remaining: 7.77s
# 188:	learn: 0.2411873	total: 4.99s	remaining: 7.74s
# 189:	learn: 0.2411585	total: 5.02s	remaining: 7.71s
# 190:	learn: 0.2411349	total: 5.04s	remaining: 7.68s
# 191:	learn: 0.2410778	total: 5.07s	remaining: 7.65s
# 192:	learn: 0.2410470	total: 5.09s	remaining: 7.62s
# 193:	learn: 0.2410080	total: 5.11s	remaining: 7.59s
# 194:	learn: 0.2409479	total: 5.14s	remaining: 7.56s
# 195:	learn: 0.2409187	total: 5.16s	remaining: 7.54s
# 196:	learn: 0.2408810	total: 5.19s	remaining: 7.5s
# 197:	learn: 0.2408540	total: 5.21s	remaining: 7.47s
# 198:	learn: 0.2407878	total: 5.24s	remaining: 7.45s
# 199:	learn: 0.2407578	total: 5.26s	remaining: 7.42s
# 200:	learn: 0.2407180	total: 5.29s	remaining: 7.39s
# 201:	learn: 0.2406824	total: 5.32s	remaining: 7.37s
# 202:	learn: 0.2406529	total: 5.34s	remaining: 7.34s
# 203:	learn: 0.2406270	total: 5.37s	remaining: 7.31s
# 204:	learn: 0.2405898	total: 5.39s	remaining: 7.28s
# 205:	learn: 0.2405550	total: 5.42s	remaining: 7.25s
# 206:	learn: 0.2405296	total: 5.44s	remaining: 7.23s
# 207:	learn: 0.2404896	total: 5.47s	remaining: 7.2s
# 208:	learn: 0.2404705	total: 5.49s	remaining: 7.17s
# 209:	learn: 0.2404442	total: 5.51s	remaining: 7.14s
# 210:	learn: 0.2403876	total: 5.54s	remaining: 7.11s
# 211:	learn: 0.2403369	total: 5.56s	remaining: 7.09s
# 212:	learn: 0.2403039	total: 5.59s	remaining: 7.06s
# 213:	learn: 0.2402812	total: 5.61s	remaining: 7.03s
# 214:	learn: 0.2402477	total: 5.64s	remaining: 7s
# 215:	learn: 0.2402163	total: 5.67s	remaining: 6.98s
# 216:	learn: 0.2401876	total: 5.69s	remaining: 6.95s
# 217:	learn: 0.2401320	total: 5.72s	remaining: 6.93s
# 218:	learn: 0.2400989	total: 5.76s	remaining: 6.91s
# 219:	learn: 0.2400654	total: 5.79s	remaining: 6.89s
# 220:	learn: 0.2400359	total: 5.81s	remaining: 6.87s
# 221:	learn: 0.2400037	total: 5.84s	remaining: 6.84s
# 222:	learn: 0.2399649	total: 5.87s	remaining: 6.82s
# 223:	learn: 0.2399397	total: 5.89s	remaining: 6.79s
# 224:	learn: 0.2398962	total: 5.92s	remaining: 6.76s
# 225:	learn: 0.2398642	total: 5.95s	remaining: 6.74s
# 226:	learn: 0.2398319	total: 5.98s	remaining: 6.72s
# 227:	learn: 0.2398005	total: 6.01s	remaining: 6.69s
# 228:	learn: 0.2397782	total: 6.03s	remaining: 6.66s
# 229:	learn: 0.2397411	total: 6.06s	remaining: 6.64s
# 230:	learn: 0.2397102	total: 6.08s	remaining: 6.61s
# 231:	learn: 0.2396813	total: 6.11s	remaining: 6.58s
# 232:	learn: 0.2396570	total: 6.13s	remaining: 6.55s
# 233:	learn: 0.2396290	total: 6.16s	remaining: 6.53s
# 234:	learn: 0.2396059	total: 6.18s	remaining: 6.5s
# 235:	learn: 0.2395651	total: 6.21s	remaining: 6.47s
# 236:	learn: 0.2395437	total: 6.24s	remaining: 6.45s
# 237:	learn: 0.2395149	total: 6.27s	remaining: 6.43s
# 238:	learn: 0.2394823	total: 6.3s	remaining: 6.41s
# 239:	learn: 0.2394654	total: 6.33s	remaining: 6.38s
# 240:	learn: 0.2394441	total: 6.35s	remaining: 6.35s
# 241:	learn: 0.2394133	total: 6.37s	remaining: 6.32s
# 242:	learn: 0.2393889	total: 6.39s	remaining: 6.29s
# 243:	learn: 0.2393557	total: 6.42s	remaining: 6.26s
# 244:	learn: 0.2393214	total: 6.44s	remaining: 6.23s
# 245:	learn: 0.2392932	total: 6.47s	remaining: 6.2s
# 246:	learn: 0.2392728	total: 6.49s	remaining: 6.18s
# 247:	learn: 0.2392413	total: 6.51s	remaining: 6.15s
# 248:	learn: 0.2392077	total: 6.54s	remaining: 6.12s
# 249:	learn: 0.2391833	total: 6.56s	remaining: 6.09s
# 250:	learn: 0.2391582	total: 6.59s	remaining: 6.06s
# 251:	learn: 0.2391232	total: 6.61s	remaining: 6.03s
# 252:	learn: 0.2390973	total: 6.63s	remaining: 6s
# 253:	learn: 0.2390808	total: 6.66s	remaining: 5.98s
# 254:	learn: 0.2390633	total: 6.68s	remaining: 5.95s
# 255:	learn: 0.2390315	total: 6.7s	remaining: 5.92s
# 256:	learn: 0.2390010	total: 6.73s	remaining: 5.89s
# 257:	learn: 0.2389768	total: 6.75s	remaining: 5.86s
# 258:	learn: 0.2389548	total: 6.78s	remaining: 5.84s
# 259:	learn: 0.2389229	total: 6.8s	remaining: 5.81s
# 260:	learn: 0.2388871	total: 6.83s	remaining: 5.78s
# 261:	learn: 0.2388711	total: 6.85s	remaining: 5.75s
# 262:	learn: 0.2388507	total: 6.87s	remaining: 5.72s
# 263:	learn: 0.2388356	total: 6.89s	remaining: 5.69s
# 264:	learn: 0.2387974	total: 6.92s	remaining: 5.67s
# 265:	learn: 0.2387741	total: 6.95s	remaining: 5.64s
# 266:	learn: 0.2387470	total: 6.97s	remaining: 5.61s
# 267:	learn: 0.2387174	total: 6.99s	remaining: 5.58s
# 268:	learn: 0.2386820	total: 7.02s	remaining: 5.56s
# 269:	learn: 0.2386597	total: 7.04s	remaining: 5.53s
# 270:	learn: 0.2386263	total: 7.07s	remaining: 5.5s
# 271:	learn: 0.2385958	total: 7.09s	remaining: 5.47s
# 272:	learn: 0.2385572	total: 7.11s	remaining: 5.45s
# 273:	learn: 0.2385253	total: 7.14s	remaining: 5.42s
# 274:	learn: 0.2384964	total: 7.16s	remaining: 5.39s
# 275:	learn: 0.2384734	total: 7.19s	remaining: 5.36s
# 276:	learn: 0.2384363	total: 7.21s	remaining: 5.34s
# 277:	learn: 0.2384167	total: 7.23s	remaining: 5.31s
# 278:	learn: 0.2383891	total: 7.26s	remaining: 5.28s
# 279:	learn: 0.2383609	total: 7.28s	remaining: 5.25s
# 280:	learn: 0.2383052	total: 7.3s	remaining: 5.22s
# 281:	learn: 0.2382830	total: 7.33s	remaining: 5.2s
# 282:	learn: 0.2382392	total: 7.35s	remaining: 5.17s
# 283:	learn: 0.2382136	total: 7.38s	remaining: 5.14s
# 284:	learn: 0.2381700	total: 7.41s	remaining: 5.12s
# 285:	learn: 0.2381288	total: 7.43s	remaining: 5.09s
# 286:	learn: 0.2380912	total: 7.45s	remaining: 5.06s
# 287:	learn: 0.2380625	total: 7.48s	remaining: 5.04s
# 288:	learn: 0.2380302	total: 7.5s	remaining: 5.01s
# 289:	learn: 0.2379982	total: 7.53s	remaining: 4.98s
# 290:	learn: 0.2379759	total: 7.55s	remaining: 4.96s
# 291:	learn: 0.2379514	total: 7.58s	remaining: 4.93s
# 292:	learn: 0.2379034	total: 7.6s	remaining: 4.9s
# 293:	learn: 0.2378825	total: 7.63s	remaining: 4.88s
# 294:	learn: 0.2378458	total: 7.65s	remaining: 4.85s
# 295:	learn: 0.2378382	total: 7.67s	remaining: 4.82s
# 296:	learn: 0.2378043	total: 7.7s	remaining: 4.79s
# 297:	learn: 0.2377654	total: 7.72s	remaining: 4.77s
# 298:	learn: 0.2377462	total: 7.74s	remaining: 4.74s
# 299:	learn: 0.2377208	total: 7.77s	remaining: 4.71s
# 300:	learn: 0.2376894	total: 7.79s	remaining: 4.69s
# 301:	learn: 0.2376601	total: 7.82s	remaining: 4.66s
# 302:	learn: 0.2376353	total: 7.84s	remaining: 4.63s
# 303:	learn: 0.2376063	total: 7.87s	remaining: 4.61s
# 304:	learn: 0.2375687	total: 7.89s	remaining: 4.58s
# 305:	learn: 0.2375418	total: 7.91s	remaining: 4.55s
# 306:	learn: 0.2375101	total: 7.94s	remaining: 4.52s
# 307:	learn: 0.2374931	total: 7.96s	remaining: 4.5s
# 308:	learn: 0.2374749	total: 7.98s	remaining: 4.47s
# 309:	learn: 0.2374534	total: 8.01s	remaining: 4.44s
# 310:	learn: 0.2374242	total: 8.03s	remaining: 4.42s
# 311:	learn: 0.2374084	total: 8.05s	remaining: 4.39s
# 312:	learn: 0.2373867	total: 8.08s	remaining: 4.36s
# 313:	learn: 0.2373598	total: 8.1s	remaining: 4.33s
# 314:	learn: 0.2373316	total: 8.13s	remaining: 4.31s
# 315:	learn: 0.2372890	total: 8.15s	remaining: 4.28s
# 316:	learn: 0.2372609	total: 8.17s	remaining: 4.25s
# 317:	learn: 0.2372453	total: 8.2s	remaining: 4.23s
# 318:	learn: 0.2372267	total: 8.22s	remaining: 4.2s
# 319:	learn: 0.2371962	total: 8.24s	remaining: 4.17s
# 320:	learn: 0.2371671	total: 8.27s	remaining: 4.15s
# 321:	learn: 0.2371373	total: 8.29s	remaining: 4.12s
# 322:	learn: 0.2371107	total: 8.32s	remaining: 4.1s
# 323:	learn: 0.2370939	total: 8.34s	remaining: 4.07s
# 324:	learn: 0.2370676	total: 8.37s	remaining: 4.04s
# 325:	learn: 0.2370404	total: 8.39s	remaining: 4.01s
# 326:	learn: 0.2370183	total: 8.41s	remaining: 3.99s
# 327:	learn: 0.2369949	total: 8.43s	remaining: 3.96s
# 328:	learn: 0.2369703	total: 8.46s	remaining: 3.93s
# 329:	learn: 0.2369399	total: 8.48s	remaining: 3.91s
# 330:	learn: 0.2369177	total: 8.51s	remaining: 3.88s
# 331:	learn: 0.2368718	total: 8.53s	remaining: 3.85s
# 332:	learn: 0.2368294	total: 8.56s	remaining: 3.83s
# 333:	learn: 0.2368041	total: 8.58s	remaining: 3.8s
# 334:	learn: 0.2367910	total: 8.61s	remaining: 3.78s
# 335:	learn: 0.2367632	total: 8.63s	remaining: 3.75s
# 336:	learn: 0.2367274	total: 8.66s	remaining: 3.72s
# 337:	learn: 0.2366956	total: 8.68s	remaining: 3.7s
# 338:	learn: 0.2366654	total: 8.7s	remaining: 3.67s
# 339:	learn: 0.2366474	total: 8.72s	remaining: 3.64s
# 340:	learn: 0.2366040	total: 8.75s	remaining: 3.62s
# 341:	learn: 0.2365844	total: 8.78s	remaining: 3.59s
# 342:	learn: 0.2365717	total: 8.8s	remaining: 3.57s
# 343:	learn: 0.2365534	total: 8.82s	remaining: 3.54s
# 344:	learn: 0.2365124	total: 8.85s	remaining: 3.51s
# 345:	learn: 0.2364790	total: 8.87s	remaining: 3.49s
# 346:	learn: 0.2364389	total: 8.9s	remaining: 3.46s
# 347:	learn: 0.2364155	total: 8.92s	remaining: 3.44s
# 348:	learn: 0.2363937	total: 8.95s	remaining: 3.41s
# 349:	learn: 0.2363654	total: 8.97s	remaining: 3.38s
# 350:	learn: 0.2363289	total: 8.99s	remaining: 3.36s
# 351:	learn: 0.2363142	total: 9.02s	remaining: 3.33s
# 352:	learn: 0.2362750	total: 9.04s	remaining: 3.3s
# 353:	learn: 0.2362597	total: 9.06s	remaining: 3.28s
# 354:	learn: 0.2362226	total: 9.09s	remaining: 3.25s
# 355:	learn: 0.2362112	total: 9.11s	remaining: 3.23s
# 356:	learn: 0.2361904	total: 9.13s	remaining: 3.2s
# 357:	learn: 0.2361631	total: 9.16s	remaining: 3.17s
# 358:	learn: 0.2361339	total: 9.18s	remaining: 3.15s
# 359:	learn: 0.2361065	total: 9.21s	remaining: 3.12s
# 360:	learn: 0.2360866	total: 9.23s	remaining: 3.09s
# 361:	learn: 0.2360666	total: 9.25s	remaining: 3.07s
# 362:	learn: 0.2360205	total: 9.28s	remaining: 3.04s
# 363:	learn: 0.2360057	total: 9.3s	remaining: 3.02s
# 364:	learn: 0.2359742	total: 9.33s	remaining: 2.99s
# 365:	learn: 0.2359449	total: 9.35s	remaining: 2.96s
# 366:	learn: 0.2359195	total: 9.38s	remaining: 2.94s
# 367:	learn: 0.2358968	total: 9.4s	remaining: 2.91s
# 368:	learn: 0.2358683	total: 9.42s	remaining: 2.88s
# 369:	learn: 0.2358500	total: 9.45s	remaining: 2.86s
# 370:	learn: 0.2358149	total: 9.47s	remaining: 2.83s
# 371:	learn: 0.2357942	total: 9.49s	remaining: 2.81s
# 372:	learn: 0.2357757	total: 9.52s	remaining: 2.78s
# 373:	learn: 0.2357381	total: 9.54s	remaining: 2.76s
# 374:	learn: 0.2356942	total: 9.57s	remaining: 2.73s
# 375:	learn: 0.2356782	total: 9.6s	remaining: 2.71s
# 376:	learn: 0.2356520	total: 9.62s	remaining: 2.68s
# 377:	learn: 0.2356104	total: 9.65s	remaining: 2.65s
# 378:	learn: 0.2355856	total: 9.68s	remaining: 2.63s
# 379:	learn: 0.2355575	total: 9.7s	remaining: 2.6s
# 380:	learn: 0.2355444	total: 9.72s	remaining: 2.58s
# 381:	learn: 0.2355225	total: 9.75s	remaining: 2.55s
# 382:	learn: 0.2355013	total: 9.78s	remaining: 2.53s
# 383:	learn: 0.2354679	total: 9.8s	remaining: 2.5s
# 384:	learn: 0.2354373	total: 9.83s	remaining: 2.48s
# 385:	learn: 0.2354147	total: 9.85s	remaining: 2.45s
# 386:	learn: 0.2353856	total: 9.88s	remaining: 2.42s
# 387:	learn: 0.2353678	total: 9.91s	remaining: 2.4s
# 388:	learn: 0.2353463	total: 9.93s	remaining: 2.38s
# 389:	learn: 0.2353126	total: 9.96s	remaining: 2.35s
# 390:	learn: 0.2352829	total: 9.99s	remaining: 2.33s
# 391:	learn: 0.2352501	total: 10s	remaining: 2.3s
# 392:	learn: 0.2352179	total: 10s	remaining: 2.27s
# 393:	learn: 0.2351916	total: 10.1s	remaining: 2.25s
# 394:	learn: 0.2351615	total: 10.1s	remaining: 2.22s
# 395:	learn: 0.2351373	total: 10.1s	remaining: 2.2s
# 396:	learn: 0.2351199	total: 10.2s	remaining: 2.17s
# 397:	learn: 0.2350913	total: 10.2s	remaining: 2.15s
# 398:	learn: 0.2350708	total: 10.2s	remaining: 2.12s
# 399:	learn: 0.2350439	total: 10.2s	remaining: 2.1s
# 400:	learn: 0.2350257	total: 10.3s	remaining: 2.07s
# 401:	learn: 0.2349849	total: 10.3s	remaining: 2.04s
# 402:	learn: 0.2349575	total: 10.3s	remaining: 2.02s
# 403:	learn: 0.2349407	total: 10.3s	remaining: 1.99s
# 404:	learn: 0.2348946	total: 10.4s	remaining: 1.98s
# 405:	learn: 0.2348645	total: 10.4s	remaining: 1.95s
# 406:	learn: 0.2348246	total: 10.5s	remaining: 1.93s
# 407:	learn: 0.2347871	total: 10.5s	remaining: 1.9s
# 408:	learn: 0.2347582	total: 10.5s	remaining: 1.88s
# 409:	learn: 0.2347212	total: 10.5s	remaining: 1.85s
# 410:	learn: 0.2346987	total: 10.6s	remaining: 1.83s
# 411:	learn: 0.2346800	total: 10.6s	remaining: 1.8s
# 412:	learn: 0.2346472	total: 10.6s	remaining: 1.77s
# 413:	learn: 0.2346149	total: 10.7s	remaining: 1.75s
# 414:	learn: 0.2345998	total: 10.7s	remaining: 1.72s
# 415:	learn: 0.2345917	total: 10.7s	remaining: 1.7s
# 416:	learn: 0.2345725	total: 10.7s	remaining: 1.67s
# 417:	learn: 0.2345413	total: 10.8s	remaining: 1.65s
# 418:	learn: 0.2344905	total: 10.8s	remaining: 1.62s
# 419:	learn: 0.2344496	total: 10.8s	remaining: 1.6s
# 420:	learn: 0.2344103	total: 10.8s	remaining: 1.57s
# 421:	learn: 0.2343783	total: 10.9s	remaining: 1.55s
# 422:	learn: 0.2343488	total: 10.9s	remaining: 1.52s
# 423:	learn: 0.2343210	total: 10.9s	remaining: 1.5s
# 424:	learn: 0.2343072	total: 11s	remaining: 1.47s
# 425:	learn: 0.2342823	total: 11s	remaining: 1.45s
# 426:	learn: 0.2342559	total: 11s	remaining: 1.42s
# 427:	learn: 0.2342249	total: 11.1s	remaining: 1.39s
# 428:	learn: 0.2341992	total: 11.1s	remaining: 1.37s
# 429:	learn: 0.2341819	total: 11.1s	remaining: 1.34s
# 430:	learn: 0.2341629	total: 11.1s	remaining: 1.32s
# 431:	learn: 0.2341379	total: 11.2s	remaining: 1.29s
# 432:	learn: 0.2341142	total: 11.2s	remaining: 1.26s
# 433:	learn: 0.2340895	total: 11.2s	remaining: 1.24s
# 434:	learn: 0.2340530	total: 11.2s	remaining: 1.21s
# 435:	learn: 0.2340126	total: 11.3s	remaining: 1.19s
# 436:	learn: 0.2339752	total: 11.3s	remaining: 1.16s
# 437:	learn: 0.2339480	total: 11.3s	remaining: 1.14s
# 438:	learn: 0.2339220	total: 11.3s	remaining: 1.11s
# 439:	learn: 0.2338905	total: 11.4s	remaining: 1.08s
# 440:	learn: 0.2338572	total: 11.4s	remaining: 1.06s
# 441:	learn: 0.2338371	total: 11.4s	remaining: 1.03s
# 442:	learn: 0.2338059	total: 11.4s	remaining: 1.01s
# 443:	learn: 0.2337657	total: 11.5s	remaining: 983ms
# 444:	learn: 0.2337360	total: 11.5s	remaining: 957ms
# 445:	learn: 0.2337045	total: 11.5s	remaining: 931ms
# 446:	learn: 0.2336952	total: 11.6s	remaining: 908ms
# 447:	learn: 0.2336660	total: 11.6s	remaining: 882ms
# 448:	learn: 0.2336361	total: 11.6s	remaining: 856ms
# 449:	learn: 0.2336104	total: 11.7s	remaining: 830ms
# 450:	learn: 0.2335757	total: 11.7s	remaining: 804ms
# 451:	learn: 0.2335478	total: 11.7s	remaining: 778ms
# 452:	learn: 0.2335206	total: 11.8s	remaining: 752ms
# 453:	learn: 0.2335024	total: 11.8s	remaining: 726ms
# 454:	learn: 0.2334731	total: 11.8s	remaining: 700ms
# 455:	learn: 0.2334447	total: 11.8s	remaining: 675ms
# 456:	learn: 0.2334156	total: 11.9s	remaining: 649ms
# 457:	learn: 0.2333992	total: 11.9s	remaining: 623ms
# 458:	learn: 0.2333575	total: 11.9s	remaining: 597ms
# 459:	learn: 0.2333369	total: 11.9s	remaining: 571ms
# 460:	learn: 0.2333024	total: 12s	remaining: 546ms
# 461:	learn: 0.2332889	total: 12s	remaining: 520ms
# 462:	learn: 0.2332714	total: 12s	remaining: 494ms
# 463:	learn: 0.2332304	total: 12.1s	remaining: 468ms
# 464:	learn: 0.2332094	total: 12.1s	remaining: 442ms
# 465:	learn: 0.2331857	total: 12.1s	remaining: 416ms
# 466:	learn: 0.2331478	total: 12.1s	remaining: 390ms
# 467:	learn: 0.2331191	total: 12.2s	remaining: 364ms
# 468:	learn: 0.2330799	total: 12.2s	remaining: 338ms
# 469:	learn: 0.2330446	total: 12.2s	remaining: 312ms
# 470:	learn: 0.2330164	total: 12.2s	remaining: 286ms
# 471:	learn: 0.2329906	total: 12.3s	remaining: 260ms
# 472:	learn: 0.2329759	total: 12.3s	remaining: 234ms
# 473:	learn: 0.2329558	total: 12.3s	remaining: 208ms
# 474:	learn: 0.2329280	total: 12.3s	remaining: 182ms
# 475:	learn: 0.2329165	total: 12.4s	remaining: 156ms
# 476:	learn: 0.2328744	total: 12.4s	remaining: 130ms
# 477:	learn: 0.2328436	total: 12.4s	remaining: 104ms
# 478:	learn: 0.2328084	total: 12.5s	remaining: 78ms
# 479:	learn: 0.2327840	total: 12.5s	remaining: 52ms
# 480:	learn: 0.2327580	total: 12.5s	remaining: 26ms
# 481:	learn: 0.2327302	total: 12.5s	remaining: 0us

# %% [markdown]
# Kaggle-score = 0,73924

# %% [markdown]
# # Export to the PROD

# %% [markdown]
# Из всех моделей осталось выбрать наилучшую по Kaggle-score и дальше через FastAPI & Streamlit UI сделать полноценное приложение.

# %%
import joblib

# Save the production model
joblib.dump(pipeline_logreg, "models/pipeline_logreg.joblib")
joblib.dump(best_decision_tree, "models/best_decision_tree.joblib")
joblib.dump(best_random_forest, "models/best_random_forest.joblib")
joblib.dump(best_catboost, "models/best_catboost.joblib")
# Out:
# ['models/best_catboost.joblib']
